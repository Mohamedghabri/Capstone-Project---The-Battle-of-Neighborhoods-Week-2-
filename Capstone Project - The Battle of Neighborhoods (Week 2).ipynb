# %% [markdown]
# # Data Description

# %% [markdown]
# ### Restaurant business depends in its neighbourhood. Indeed, its profit and its cuisine is related to its costumer and the existence of other restaurants near its location. Investor are interested in get more profits and competitiveness by opening up a restaurant in best location and offering the best service depending in their costumers. So first I took the dataset according to neighborhood wise, so that it's easy for us to check the data neighborhood wise.

# %%
import pandas as pd
url='https://raw.githubusercontent.com/Auxilin/The-Battle-of-Neighborhoods/master/SFRentDataset.csv'
readfile = pd.read_csv(url)
readfile.head(13)
# Out:
#            NeighborhoodName           City State     CountyName  2018-1  \
# 0          Mission District  San Francisco    CA  San Francisco  3200.0
# 1                  Downtown  San Francisco    CA  San Francisco  2855.0
# 2           Pacific Heights  San Francisco    CA  San Francisco  3500.0
# 3                  Nob Hill  San Francisco    CA  San Francisco  2862.5
# 4           South of Market  San Francisco    CA  San Francisco  3550.0
# 5              Russian Hill  San Francisco    CA  San Francisco  3495.0
# 6              Hayes Valley  San Francisco    CA  San Francisco  3965.0
# 7                    Marina  San Francisco    CA  San Francisco  3300.0
# 8     Lower Pacific Heights  San Francisco    CA  San Francisco  3200.0
# 9               South Beach  San Francisco    CA  San Francisco  3800.0
# 10  Van Ness - Civic Center  San Francisco    CA  San Francisco  3259.0
# 11              Mission Bay  San Francisco    CA  San Francisco  3699.0
# 12      Yerba Buena Gardens  San Francisco    CA  San Francisco  3495.0
#
#     2018-2  2018-3  2018-04  2018-05  2018-06
# 0   3250.0  3195.0   3403.0   3481.0   3350.0
# 1   2950.0  3090.0   3030.0   3095.0   3095.0
# 2   3497.5  3595.0   3695.0   3719.5   3749.0
# 3   2800.0  2795.0   2795.0   2795.0   2700.0
# 4   3709.0  3729.0   3665.0   3667.5   3650.0
# 5   3447.5  3345.0   3474.0   3395.0   3350.0
# 6   4205.0  3985.0   4050.0   4175.0   4130.0
# 7   3286.5  3274.0   3300.0   3400.0   3400.0
# 8   3225.0  3307.0   3358.0   3296.0   3275.0
# 9   3900.0  3897.5   3900.0   3950.0   3925.0
# 10  3253.5  3500.0   3563.0   3500.0   3500.0
# 11  3798.0  3975.5   4013.0   4088.5   4092.5
# 12  3450.0  3620.5   3672.5   3505.0   3625.0

# %% [markdown]
# #### finalScore = (rentScore)*0.6+(ratingScore)*0.4

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
address = 'Mission District, San Francisco, CA'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Latitude and longitude of '+address+' are {}, {}.'.format(latitude, longitude))
# Out:
# C:\Users\mohamed\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.22.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# Latitude and longitude of Mission District, San Francisco, CA are 37.75993, -122.4191376.

# %%
# The code was removed by Watson Studio for sharing.

# %%
categoryId= '4bf58dd8d48988d10f941735'   #categoryID for Indian restaurant.
radius=1000                              # radius in meters

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius,
    categoryId)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-97e274113bd8> in <module>
#       3
#       4 url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'.format(
# ----> 5     CLIENT_ID,
#       6     CLIENT_SECRET,
#       7     VERSION,
#
# NameError: name 'CLIENT_ID' is not defined

# %%
#Send the GET request and examine the resutls
import requests 
results = requests.get(url).json()
results

# %%
Restaurants= len(results['response']['venues'])
print ('There are',  Restaurants , 'restaurants.')

# %% [markdown]
# ###  The venue id for first restaurant from json response.

# %%
venueid= results['response']['venues'][0]['id']
venueid
# Out:
# '5a56d8294b78c509a7e462e7'

# %%
url2 = 'https://api.foursquare.com/v2/venues/5a56d8294b78c509a7e462e7?&client_id={}&client_secret={}&v={}&ll={},{}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude
    )
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5b824b084434b92acad36f4d'},
#  'response': {'venue': {'allowMenuUrlEdit': True,
#    'attributes': {'groups': [{'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$',
#         'priceTier': 2}],
#       'name': 'Price',
#       'summary': '$$',
#       'type': 'price'},
#      {'count': 3,
#       'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}],
#       'name': 'Reservations',
#       'summary': 'Reservations',
#       'type': 'reservations'},
#      {'count': 7,
#       'items': [{'displayName': 'Credit Cards',
#         'displayValue': 'Yes (incl. Discover & Visa)'}],
#       'name': 'Credit Cards',
#       'summary': 'Credit Cards',
#       'type': 'payments'},
#      {'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}],
#       'name': 'Outdoor Seating',
#       'type': 'outdoorSeating'},
#      {'count': 1,
#       'items': [{'displayName': 'Wi-Fi', 'displayValue': 'No'}],
#       'name': 'Wi-Fi',
#       'type': 'wifi'},
#      {'count': 8,
#       'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#        {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#        {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#        {'displayName': 'Dessert', 'displayValue': 'Dessert'}],
#       'name': 'Menus',
#       'summary': 'Dessert, Brunch & more',
#       'type': 'serves'},
#      {'count': 5,
#       'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#        {'displayName': 'Wine', 'displayValue': 'Wine'}],
#       'name': 'Drinks',
#       'summary': 'Beer & Wine',
#       'type': 'drinks'},
#      {'count': 5,
#       'items': [{'displayName': 'Take-out', 'displayValue': 'Take-out'},
#        {'displayName': 'Delivery', 'displayValue': 'Delivery'}],
#       'name': 'Dining Options',
#       'summary': 'Take-out & Delivery',
#       'type': 'diningOptions'}]},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'bestPhoto': {'createdAt': 1529726795,
#     'height': 1920,
#     'id': '5b2dc74b5d891b002c8b3cc5',
#     'prefix': 'https://igx.4sqi.net/img/general/',
#     'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#     'suffix': '/408415078_DTqJdzk2vXS3YBRFBtsUV_NZ8LEWSjgSLGm6RB_Sihw.jpg',
#     'visibility': 'public',
#     'width': 1440},
#    'canonicalUrl': 'https://foursquare.com/v/lotus-sf-indian-cuisine/5a56d8294b78c509a7e462e7',
#    'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10f941735',
#      'name': 'Indian Restaurant',
#      'pluralName': 'Indian Restaurants',
#      'primary': True,
#      'shortName': 'Indian'},
#     {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan'},
#     {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/glutenfree_',
#       'suffix': '.png'},
#      'id': '4c2cd86ed066bed06c3c5209',
#      'name': 'Gluten-free Restaurant',
#      'pluralName': 'Gluten-free Restaurants',
#      'shortName': 'Gluten-free'}],
#    'contact': {'facebook': '1874149989490763',
#     'facebookName': 'Lotus SF',
#     'facebookUsername': 'lotussfcuisineofindia',
#     'formattedPhone': '(415) 872-9130',
#     'instagram': 'lotussfcuisineofindia',
#     'phone': '4158729130',
#     'twitter': 'sflotus'},
#    'createdAt': 1515640873,
#    'delivery': {'id': '720691',
#     'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#       'prefix': 'https://igx.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'grubhub'},
#     'url': 'https://www.grubhub.com/restaurant/lotus-sf-indian-cuisine-2434-mission-st-san-francisco/720691?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=720691'},
#    'description': 'This new Indian restaurant in the Mission is on a mission.\nLotus SF serves a modern take on traditional North Indian\ncuisine that is clean, healthy and green. Plenty of vegan, vegetarian\nand gluten-free meals. Everyone says it’s absolutely delicious!',
#    'dislike': False,
#    'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#    'hours': {'dayData': [],
#     'isLocalHoliday': False,
#     'isOpen': False,
#     'richStatus': {'entities': [], 'text': 'Closed until 11:30 AM tomorrow'},
#     'status': 'Closed until 11:30 AM tomorrow',
#     'timeframes': [{'days': 'Mon–Thu, Sun',
#       'open': [{'renderedTime': '11:30 AM–2:30 PM'},
#        {'renderedTime': '5:00 PM–9:30 PM'}],
#       'segments': []},
#      {'days': 'Fri–Sat',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–2:30 PM'},
#        {'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'id': '5a56d8294b78c509a7e462e7',
#    'inbox': {'count': 0, 'items': []},
#    'likes': {'count': 13,
#     'groups': [{'count': 13, 'items': [], 'type': 'others'}],
#     'summary': '13 Likes'},
#    'listed': {'count': 10,
#     'groups': [{'count': 10,
#       'items': [{'canonicalUrl': 'https://foursquare.com/briannacadalzo/list/san-fran-eats',
#         'collaborative': False,
#         'createdAt': 1494389950,
#         'description': '',
#         'editable': False,
#         'followers': {'count': 0},
#         'id': '591294be295513094e59b937',
#         'listItems': {'count': 48,
#          'items': [{'createdAt': 1524544796,
#            'id': 'v5a56d8294b78c509a7e462e7'}]},
#         'name': 'San Fran Eats',
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1528648151,
#         'url': '/briannacadalzo/list/san-fran-eats',
#         'user': {'firstName': 'Brianna',
#          'gender': 'female',
#          'id': '18774533',
#          'lastName': 'Cadalzo',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/YZBSVZR3F2J2JMRY.jpg'}}},
#        {'canonicalUrl': 'https://foursquare.com/user/135686788/list/mission',
#         'collaborative': False,
#         'createdAt': 1503278150,
#         'description': 'Near Capp St. Apt.',
#         'editable': False,
#         'followers': {'count': 1},
#         'id': '599a3446249623221b797d01',
#         'listItems': {'count': 61,
#          'items': [{'createdAt': 1516517628,
#            'id': 'v5a56d8294b78c509a7e462e7'}]},
#         'name': 'Mission',
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1526769257,
#         'url': '/user/135686788/list/mission',
#         'user': {'firstName': 'Mark',
#          'gender': 'male',
#          'id': '135686788',
#          'lastName': 'Cialone',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/135686788-3N1IYMJJ4Q1N32ET.jpg'}}},
#        {'canonicalUrl': 'https://foursquare.com/user/149831930/list/want-to-nom',
#         'collaborative': True,
#         'createdAt': 1473644477,
#         'description': 'Boba.\nBakeries.\nBars.\nRamen.\n(etc)',
#         'editable': False,
#         'followers': {'count': 1},
#         'id': '57d607bd498e78eea071e739',
#         'listItems': {'count': 97,
#          'items': [{'createdAt': 1523177097,
#            'id': 'v5a56d8294b78c509a7e462e7'}]},
#         'name': 'Want To Nom',
#         'photo': {'createdAt': 1450070994,
#          'height': 1920,
#          'id': '566e53d2498e266e0fc6f1b0',
#          'prefix': 'https://igx.4sqi.net/img/general/',
#          'suffix': '/86875692_LbaL6esrrZlvVMKE4b4wQhcrPptNkdWiI0dXDsi89gg.jpg',
#          'user': {'firstName': 'Spencer',
#           'gender': 'male',
#           'id': '86875692',
#           'lastName': 'Costanzo',
#           'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#            'suffix': '/86875692-152N1D4ZXF4QPBLJ'}},
#          'visibility': 'public',
#          'width': 1440},
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1533263051,
#         'url': '/user/149831930/list/want-to-nom',
#         'user': {'firstName': 'Nathan',
#          'gender': 'none',
#          'id': '149831930',
#          'lastName': 'L',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/149831930-YYLQ34JKHAEFIH42'}}},
#        {'canonicalUrl': 'https://foursquare.com/user/7986598/list/to-try-sf',
#         'collaborative': False,
#         'createdAt': 1523817861,
#         'description': '',
#         'editable': False,
#         'followers': {'count': 0},
#         'id': '5ad39d852347240271c4df51',
#         'listItems': {'count': 7,
#          'items': [{'createdAt': 1523817959,
#            'id': 'v5a56d8294b78c509a7e462e7'}]},
#         'name': 'To Try SF',
#         'photo': {'createdAt': 1523500120,
#          'height': 1920,
#          'id': '5acec458ccad6b6664630f9e',
#          'prefix': 'https://igx.4sqi.net/img/general/',
#          'suffix': '/168372_dlgX_om_iwVYyfJjkOHbYZGfA-jZ1-WfpR1w2r7bzOs.jpg',
#          'user': {'firstName': 'Sam',
#           'gender': 'male',
#           'id': '168372',
#           'lastName': 'Duboff',
#           'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#            'suffix': '/5H4YBPTIB0ZDNA1E.jpg'}},
#          'visibility': 'public',
#          'width': 1080},
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1523818060,
#         'url': '/user/7986598/list/to-try-sf',
#         'user': {'firstName': 'Andrew',
#          'gender': 'male',
#          'id': '7986598',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/7986598-QMTW4RXXVCAY2HYR.jpg'}}}],
#       'name': 'Lists from other people',
#       'type': 'others'}]},
#    'location': {'address': '2434 Mission St',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'country': 'United States',
#     'distance': 215,
#     'formattedAddress': ['2434 Mission St',
#      'San Francisco, CA 94110',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.75799598854246,
#       'lng': -122.41903896674205}],
#     'lat': 37.75799598854246,
#     'lng': -122.41903896674205,
#     'postalCode': '94110',
#     'state': 'CA'},
#    'menu': {'anchor': 'View Menu',
#     'externalUrl': 'http://lotussanfrancisco.com/pdf/Lotus%20SF%20Menu.pdf',
#     'label': 'Menu',
#     'mobileUrl': 'http://lotussanfrancisco.com/pdf/Lotus%20SF%20Menu.pdf',
#     'type': 'Menu',
#     'url': 'http://lotussanfrancisco.com/pdf/Lotus%20SF%20Menu.pdf'},
#    'name': 'Lotus SF Indian Cuisine',
#    'ok': False,
#    'pageUpdates': {'count': 0, 'items': []},
#    'photos': {'count': 9,
#     'groups': [{'count': 0,
#       'items': [],
#       'name': "Friends' check-in photos",
#       'type': 'checkin'},
#      {'count': 9,
#       'items': [{'createdAt': 1529726795,
#         'height': 1920,
#         'id': '5b2dc74b5d891b002c8b3cc5',
#         'prefix': 'https://igx.4sqi.net/img/general/',
#         'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#         'suffix': '/408415078_DTqJdzk2vXS3YBRFBtsUV_NZ8LEWSjgSLGm6RB_Sihw.jpg',
#         'user': {'firstName': 'Jia',
#          'gender': 'female',
#          'id': '408415078',
#          'lastName': 'Han',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/408415078_zIA8MqGk_UUeHsSeiLhGapfF4Wr7Zw_DkXpog2Iwrd72fFynhC3pRN4S39gzu94nJN27MmExw.jpg'}},
#         'visibility': 'public',
#         'width': 1440}],
#       'name': 'Venue photos',
#       'type': 'venue'}],
#     'summary': '0 photos'},
#    'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#    'rating': 7.0,
#    'ratingColor': 'C5DE35',
#    'ratingSignals': 22,
#    'reasons': {'count': 0, 'items': []},
#    'shortUrl': 'http://4sq.com/2Dh2l2K',
#    'specials': {'count': 0, 'items': []},
#    'stats': {'tipCount': 5},
#    'timeZone': 'America/Los_Angeles',
#    'tips': {'count': 5,
#     'groups': [{'count': 5,
#       'items': [{'agreeCount': 0,
#         'authorInteractionType': 'liked',
#         'canonicalUrl': 'https://foursquare.com/item/5b2daef1c53093002cc79d82',
#         'createdAt': 1529720561,
#         'disagreeCount': 0,
#         'id': '5b2daef1c53093002cc79d82',
#         'lang': 'en',
#         'likes': {'count': 0, 'groups': []},
#         'logView': True,
#         'text': 'Everything I had was awesome',
#         'todo': {'count': 0},
#         'type': 'user',
#         'user': {'firstName': 'Mark',
#          'gender': 'male',
#          'id': '135686788',
#          'lastName': 'Cialone',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/135686788-3N1IYMJJ4Q1N32ET.jpg'}}}],
#       'name': 'All tips',
#       'type': 'others'}]},
#    'url': 'https://lotussanfrancisco.com',
#    'verified': False}}}

# %%
restaurantrating= results2['response']['venue']['rating']
restaurantrating
# Out:
# 7.0
